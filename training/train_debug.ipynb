# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parents[0]))

from data.read_data import audioImporter
from models.wav2vec_encoder import Wav2VecEncoder
from torch.utils.data import DataLoader

dataset = audioImporter("../data/LibriSpeech/train-clean-5")
loader = DataLoader(dataset, batch_size = 1)

encoder = Wav2VecEncoder(pos_type = "conv")

for waveform in loader:
    out = encoder(waveform)
    print("Waveform:", waveform.shape)
    print("Encoder out:", out.shape)
    break
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 6
#       2 from pathlib import Path
#       3 sys.path.append(str(Path.cwd().parents[0]))
#       4
#       5 from data.read_data import audioImporter
# ----> 6 from models.wav2vec_encoder import Wav2VecEncoder
#       7 from torch.utils.data import DataLoader
#       8
#       9 dataset = audioImporter("../data/LibriSpeech/train-clean-5")
#
# File c:\Users\mowen\OneDrive\Documents\Academic\Spring 2026\CS577\Project\cs577-final-project-wav2vec\models\wav2vec_encoder.py:4
#       1 import torch
#       2 import torch.nn as nn
# ----> 4 from feature_encoder import Wav2VecFeatureEncoder
#       5 from positional_conv import PositionalConvEmbedding
#       7 class Wav2VecEncoder(nn.Module):
#
# ModuleNotFoundError: No module named 'feature_encoder'

# %%
print(len(loader))
# Out:
# 1519
